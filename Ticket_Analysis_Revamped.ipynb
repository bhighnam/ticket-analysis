# %% [markdown]
# <a href="https://colab.research.google.com/github/bhighnam/ticket-analysis/blob/main/Ticket_Analysis_Revamped.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# !pip install kaleido==0.2.1
# !pip install df2img==0.2.18
import df2img
import numpy as np
# import matplotlib.ticker as ticker
# Out:
# Collecting kaleido==0.2.1
#   Using cached kaleido-0.2.1-py2.py3-none-manylinux1_x86_64.whl.metadata (15 kB)
# Using cached kaleido-0.2.1-py2.py3-none-manylinux1_x86_64.whl (79.9 MB)
# Installing collected packages: kaleido
#   Attempting uninstall: kaleido
#     Found existing installation: kaleido 0.0.3
#     Uninstalling kaleido-0.0.3:
#       Successfully uninstalled kaleido-0.0.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# df2img 0.2.18 requires kaleido==0.0.3, but you have kaleido 0.2.1 which is incompatible.
# Successfully installed kaleido-0.2.1
# Requirement already satisfied: df2img==0.2.18 in /usr/local/lib/python3.10/dist-packages (0.2.18)
# Collecting kaleido==0.0.3 (from df2img==0.2.18)
#   Using cached kaleido-0.0.3-py2.py3-none-manylinux2014_x86_64.whl.metadata (14 kB)
# Requirement already satisfied: pandas<3.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from df2img==0.2.18) (2.0.3)
# Requirement already satisfied: plotly<6.0.0,>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from df2img==0.2.18) (5.15.0)
# Requirement already satisfied: ipython>=8.12.2 in /usr/local/lib/python3.10/dist-packages (from df2img==0.2.18) (8.26.0)
# Requirement already satisfied: nbformat>=5.9.2 in /usr/local/lib/python3.10/dist-packages (from df2img==0.2.18) (5.10.4)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=8.12.2->df2img==0.2.18) (4.4.2)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython>=8.12.2->df2img==0.2.18) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=8.12.2->df2img==0.2.18) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /usr/local/lib/python3.10/dist-packages (from ipython>=8.12.2->df2img==0.2.18) (3.0.47)
# Requirement already satisfied: pygments>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=8.12.2->df2img==0.2.18) (2.16.1)
# Requirement already satisfied: stack-data in /usr/local/lib/python3.10/dist-packages (from ipython>=8.12.2->df2img==0.2.18) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=8.12.2->df2img==0.2.18) (5.14.3)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from ipython>=8.12.2->df2img==0.2.18) (1.2.2)
# Requirement already satisfied: typing-extensions>=4.6 in /usr/local/lib/python3.10/dist-packages (from ipython>=8.12.2->df2img==0.2.18) (4.12.2)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=8.12.2->df2img==0.2.18) (4.9.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.10/dist-packages (from nbformat>=5.9.2->df2img==0.2.18) (2.20.0)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat>=5.9.2->df2img==0.2.18) (4.23.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.10/dist-packages (from nbformat>=5.9.2->df2img==0.2.18) (5.7.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0.0,>=1.0.0->df2img==0.2.18) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0.0,>=1.0.0->df2img==0.2.18) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0.0,>=1.0.0->df2img==0.2.18) (2024.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0.0,>=1.0.0->df2img==0.2.18) (1.25.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly<6.0.0,>=5.0.0->df2img==0.2.18) (8.5.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly<6.0.0,>=5.0.0->df2img==0.2.18) (24.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=8.12.2->df2img==0.2.18) (0.8.4)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat>=5.9.2->df2img==0.2.18) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat>=5.9.2->df2img==0.2.18) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat>=5.9.2->df2img==0.2.18) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat>=5.9.2->df2img==0.2.18) (0.19.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core!=5.0.*,>=4.12->nbformat>=5.9.2->df2img==0.2.18) (4.2.2)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=8.12.2->df2img==0.2.18) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=8.12.2->df2img==0.2.18) (0.2.13)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas<3.0.0,>=1.0.0->df2img==0.2.18) (1.16.0)
# Requirement already satisfied: executing>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from stack-data->ipython>=8.12.2->df2img==0.2.18) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from stack-data->ipython>=8.12.2->df2img==0.2.18) (2.4.1)
# Requirement already satisfied: pure-eval in /usr/local/lib/python3.10/dist-packages (from stack-data->ipython>=8.12.2->df2img==0.2.18) (0.2.3)
# Using cached kaleido-0.0.3-py2.py3-none-manylinux2014_x86_64.whl (73.9 MB)
# Installing collected packages: kaleido
#   Attempting uninstall: kaleido
#     Found existing installation: kaleido 0.2.1
#     Uninstalling kaleido-0.2.1:
#       Successfully uninstalled kaleido-0.2.1
# Successfully installed kaleido-0.0.3

# %%
# df = pd.read_csv("/content/drive/MyDrive/Work/July_to_August_2022_incidents.csv", encoding="ISO-8859-1")
# /content/drive/MyDrive/April-June 2023.csv
# df = pd.read_csv("/content/drive/MyDrive/April-June 2023.csv", encoding="ISO-8859-1")
df = pd.read_csv("/content/drive/MyDrive/incident (9).csv", encoding="ISO-8859-1")
print(df.shape)
df.head(2)

def add_apps_column(df):
  if (df['u_business_service'] == 'Research Administration & Compliance Systems > Research Administration and Management > Research Administration & Compliance Reporting'):
                        return "RACR"
  elif (df['u_business_service'] == 'Research Administration & Compliance Systems > Research Administration and Management > Grants Management (GMAS)'):
                        return "GMAS"
  elif (df['u_business_service'] == 'Research Administration & Compliance Systems > Research Compliance > IRB (ESTR)'):
                        return "H-Apps"
  elif (df['u_business_service'] == 'Research Administration & Compliance Systems > Research Compliance > Agreements'):
                        return "H-Apps"
  elif (df['u_business_service'] == 'Research Administration & Compliance Systems > Research Compliance > Outside Activity and Interest Reporting (OAIR)'):
                        return "H-Apps"
  elif (df['u_business_service'] == 'Research Administration & Compliance Systems > Research Compliance > Data Safety'):
                        return "H-Apps"
  elif (df['u_business_service'] == 'Research Administration & Compliance Systems > Research Administration and Management > Effort Reporting (ECRT)'):
                        return "ECRT"
  elif (df['u_business_service'] == 'Research Administration & Compliance Systems > Research Administration and Management > PI Dashboard'):
                        return "PI-Dashboard"
  elif (df['u_business_service'] == 'Research Administration & Compliance Systems > Research Administration and Management > Research Administration Portal'):
                        return "Admin Portal"
  else:
                        return df['u_business_service']

# print(df.assignment_group.unique())
# print(df.u_business_service.unique())

df['Service_Group'] = df.apply(add_apps_column, axis = 1)
# print(df.u_business_service.unique(), "\n")
print(df.Service_Group.unique(), "\n", "\n")

service_group_unique = df.Service_Group.unique()

print( f"service_group_unique type --> {type(service_group_unique)}" )

for index in service_group_unique:
  print( f"index ==> {index}" )

for service_group in df['Service_Group']:
  print( f"service_group ==> {service_group}" )

# adding a column for month
df['month'] = pd.DatetimeIndex(df['sys_created_on']).month

# filling issue codes with Request if they are NA values
df['u_issue_code'] = df['u_issue_code'].fillna("Request")
# print(df.columns)
# Out:
# (2755, 21)
# ['H-Apps' 'GMAS' 'RACR' 'ECRT'
#  'Managed Servers and DevOps > Managed Servers and Databases'
#  'Admin Portal' 'PI-Dashboard'
#  'Enterprise Data Analysis and Reporting > Business Intelligence development'
#  'IT Tools > Scheduling' 'Network Services > VPN'
#  'Enterprise Data Analysis and Reporting > Business Intelligence application services'
#  'IT Tools > Source Code Version Control'
#  'Enterprise Data Analysis and Reporting > Business Intelligence platform management'
#  'Enterprise Data Integration > Integrated Data application services'
#  'Server Administration > Database Services'
#  'Secure Computing > Privileged Account Management'
#  'Network Services > Network Self-Service Tools'
#  'Enterprise Data Integration > Integrated Data development'
#  'HGSE - Network > VPN Access']
#
#
# service_group_unique type --> <class 'numpy.ndarray'>
# index ==> H-Apps
# index ==> GMAS
# index ==> RACR
# index ==> ECRT
# index ==> Managed Servers and DevOps > Managed Servers and Databases
# index ==> Admin Portal
# index ==> PI-Dashboard
# index ==> Enterprise Data Analysis and Reporting > Business Intelligence development
# index ==> IT Tools > Scheduling
# index ==> Network Services > VPN
# index ==> Enterprise Data Analysis and Reporting > Business Intelligence application services
# index ==> IT Tools > Source Code Version Control
# index ==> Enterprise Data Analysis and Reporting > Business Intelligence platform management
# index ==> Enterprise Data Integration > Integrated Data application services
# index ==> Server Administration > Database Services
# index ==> Secure Computing > Privileged Account Management
# index ==> Network Services > Network Self-Service Tools
# index ==> Enterprise Data Integration > Integrated Data development
# index ==> HGSE - Network > VPN Access
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> RACR
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> RACR
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> Managed Servers and DevOps > Managed Servers and Databases
# service_group ==> Admin Portal
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> PI-Dashboard
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> RACR
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> RACR
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> RACR
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> RACR
# service_group ==> RACR
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> RACR
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> RACR
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> PI-Dashboard
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> RACR
# service_group ==> PI-Dashboard
# service_group ==> RACR
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> RACR
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> RACR
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> Enterprise Data Analysis and Reporting > Business Intelligence development
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> RACR
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> PI-Dashboard
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> RACR
# service_group ==> RACR
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> PI-Dashboard
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> RACR
# service_group ==> RACR
# service_group ==> RACR
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> RACR
# service_group ==> RACR
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> PI-Dashboard
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> PI-Dashboard
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> RACR
# service_group ==> RACR
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> RACR
# service_group ==> RACR
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> RACR
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> RACR
# service_group ==> PI-Dashboard
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> RACR
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> PI-Dashboard
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> RACR
# service_group ==> PI-Dashboard
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> RACR
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> RACR
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> RACR
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> RACR
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> RACR
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> RACR
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> RACR
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> Managed Servers and DevOps > Managed Servers and Databases
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> RACR
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> RACR
# service_group ==> RACR
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> PI-Dashboard
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> RACR
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> RACR
# service_group ==> RACR
# service_group ==> RACR
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> PI-Dashboard
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> RACR
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> ECRT
# service_group ==> PI-Dashboard
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> RACR
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> RACR
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> RACR
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> RACR
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> PI-Dashboard
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> RACR
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> RACR
# service_group ==> ECRT
# service_group ==> RACR
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> PI-Dashboard
# service_group ==> H-Apps
# service_group ==> PI-Dashboard
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> IT Tools > Scheduling
# service_group ==> IT Tools > Scheduling
# service_group ==> IT Tools > Scheduling
# service_group ==> IT Tools > Scheduling
# service_group ==> IT Tools > Scheduling
# service_group ==> IT Tools > Scheduling
# service_group ==> IT Tools > Scheduling
# service_group ==> IT Tools > Scheduling
# service_group ==> IT Tools > Scheduling
# service_group ==> RACR
# service_group ==> RACR
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> Network Services > VPN
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> RACR
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> RACR
# service_group ==> ECRT
# service_group ==> RACR
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> PI-Dashboard
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> RACR
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> PI-Dashboard
# service_group ==> PI-Dashboard
# service_group ==> ECRT
# service_group ==> RACR
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> PI-Dashboard
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> RACR
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> RACR
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> RACR
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> RACR
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> GMAS
# service_group ==> RACR
# service_group ==> GMAS
# service_group ==> PI-Dashboard
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> PI-Dashboard
# service_group ==> RACR
# service_group ==> GMAS
# service_group ==> RACR
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> RACR
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> PI-Dashboard
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> Enterprise Data Analysis and Reporting > Business Intelligence application services
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> GMAS
# service_group ==> RACR
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> RACR
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> RACR
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> PI-Dashboard
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> PI-Dashboard
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> RACR
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> RACR
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> PI-Dashboard
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> PI-Dashboard
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> PI-Dashboard
# service_group ==> H-Apps
# service_group ==> Admin Portal
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> RACR
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> RACR
# service_group ==> IT Tools > Source Code Version Control
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> RACR
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> RACR
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> RACR
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> PI-Dashboard
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> RACR
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> PI-Dashboard
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> Enterprise Data Analysis and Reporting > Business Intelligence platform management
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> PI-Dashboard
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> GMAS
# service_group ==> RACR
# service_group ==> GMAS
# service_group ==> RACR
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> RACR
# service_group ==> ECRT
# service_group ==> RACR
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> Enterprise Data Integration > Integrated Data application services
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> RACR
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> PI-Dashboard
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> RACR
# service_group ==> RACR
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> RACR
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> RACR
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> PI-Dashboard
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> PI-Dashboard
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> Admin Portal
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> RACR
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> PI-Dashboard
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> PI-Dashboard
# service_group ==> RACR
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> RACR
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> RACR
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> RACR
# service_group ==> RACR
# service_group ==> RACR
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> GMAS
# service_group ==> RACR
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> PI-Dashboard
# service_group ==> RACR
# service_group ==> Server Administration > Database Services
# service_group ==> Server Administration > Database Services
# service_group ==> Server Administration > Database Services
# service_group ==> Server Administration > Database Services
# service_group ==> Server Administration > Database Services
# service_group ==> Server Administration > Database Services
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> PI-Dashboard
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> RACR
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> Secure Computing > Privileged Account Management
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> RACR
# service_group ==> RACR
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> RACR
# service_group ==> ECRT
# service_group ==> Network Services > Network Self-Service Tools
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> PI-Dashboard
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> RACR
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> RACR
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> RACR
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> RACR
# service_group ==> RACR
# ...
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> Enterprise Data Integration > Integrated Data development
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> RACR
# service_group ==> RACR
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> Enterprise Data Integration > Integrated Data application services
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> IT Tools > Scheduling
# service_group ==> IT Tools > Scheduling
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> PI-Dashboard
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> RACR
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> RACR
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> PI-Dashboard
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> Admin Portal
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> RACR
# service_group ==> IT Tools > Scheduling
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> PI-Dashboard
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> PI-Dashboard
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> PI-Dashboard
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> RACR
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> IT Tools > Scheduling
# service_group ==> IT Tools > Scheduling
# service_group ==> IT Tools > Scheduling
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> IT Tools > Scheduling
# service_group ==> IT Tools > Scheduling
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> PI-Dashboard
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> Admin Portal
# service_group ==> Admin Portal
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> RACR
# service_group ==> Admin Portal
# service_group ==> RACR
# service_group ==> IT Tools > Scheduling
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> Admin Portal
# service_group ==> Admin Portal
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> GMAS
# service_group ==> RACR
# service_group ==> HGSE - Network > VPN Access
# service_group ==> RACR
# service_group ==> Admin Portal
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> Admin Portal
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> RACR
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> PI-Dashboard
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> RACR
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> Admin Portal
# service_group ==> H-Apps
# service_group ==> Admin Portal
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> RACR
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> RACR
# service_group ==> RACR
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> RACR
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> RACR
# service_group ==> RACR
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> Admin Portal
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> RACR
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> ECRT
# service_group ==> RACR
# service_group ==> RACR
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> RACR
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> RACR
# service_group ==> RACR
# service_group ==> RACR
# service_group ==> Admin Portal
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> Admin Portal
# service_group ==> RACR
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> Admin Portal
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> Admin Portal
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> Admin Portal
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> Admin Portal
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> Admin Portal
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> RACR
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> PI-Dashboard
# service_group ==> Managed Servers and DevOps > Managed Servers and Databases
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> PI-Dashboard
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> ECRT
# service_group ==> H-Apps
# service_group ==> GMAS
# service_group ==> Admin Portal
# service_group ==> GMAS
# service_group ==> GMAS
# service_group ==> RACR
# service_group ==> ECRT
# service_group ==> GMAS
# service_group ==> ECRT
# service_group ==> ECRT
# service_group ==> Admin Portal
# service_group ==> RACR
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps
# service_group ==> H-Apps

# %%
df.u_business_service.value_counts()
# Out:
# u_business_service
# Research Administration & Compliance Systems > Research Administration and Management > Grants Management (GMAS)                          855
# Research Administration & Compliance Systems > Research Administration and Management > Effort Reporting (ECRT)                           477
# Research Administration & Compliance Systems > Research Compliance > IRB (ESTR)                                                           408
# Research Administration & Compliance Systems > Research Compliance > Outside Activity and Interest Reporting (OAIR)                       341
# Research Administration & Compliance Systems > Research Compliance > Data Safety                                                          251
# Research Administration & Compliance Systems > Research Administration and Management > Research Administration & Compliance Reporting    241
# Research Administration & Compliance Systems > Research Compliance > Agreements                                                            70
# Research Administration & Compliance Systems > Research Administration and Management > PI Dashboard                                       49
# Research Administration & Compliance Systems > Research Administration and Management > Research Administration Portal                     24
# IT Tools > Scheduling                                                                                                                      19
# Server Administration > Database Services                                                                                                   6
# Managed Servers and DevOps > Managed Servers and Databases                                                                                  3
# Enterprise Data Integration > Integrated Data application services                                                                          2
# Enterprise Data Analysis and Reporting > Business Intelligence development                                                                  1
# Network Services > VPN                                                                                                                      1
# Enterprise Data Analysis and Reporting > Business Intelligence application services                                                         1
# IT Tools > Source Code Version Control                                                                                                      1
# Enterprise Data Analysis and Reporting > Business Intelligence platform management                                                          1
# Secure Computing > Privileged Account Management                                                                                            1
# Network Services > Network Self-Service Tools                                                                                               1
# Enterprise Data Integration > Integrated Data development                                                                                   1
# HGSE - Network > VPN Access                                                                                                                 1
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (2755, 23)

# %%
# This is the location of RAD apps
valid_services = ["RACR", "GMAS", "H-Apps", "ECRT", "PI-Dashboard", "Admin Portal"]
valid_assignment_groups = ["ATS-RACR-Functional", "ATS - Data Safety Functional", "ATS - Research Admin Functional", "ATS - OAIR Functional",
                     "ATS - ESTR Functional", "ATS - DUA Functional", "ATS - OSP ECRT Functional", "ATS - Research Administration Portal Functional",
                     "ATS - Research Admin - Technical", "ATS - Research Admin - Dashboard"]

# %%
df = df[df.Service_Group.isin(valid_services)]
df = df[df.assignment_group.isin(valid_assignment_groups)]

# %%
df.shape
# Out:
# (2236, 23)

# %%
try:
  df['u_business_service'].mask(df['u_business_service'] == "Research Administration & Compliance Systems > Research Administration and Management > Research Administration & Compliance Reporting","RACR", inplace=True)
except Exception as NameError:
  pass

try:
  df['u_business_service'].mask(df['u_business_service'] == "Research Administration & Compliance Systems > Research Administration and Management > Effort Reporting (ECRT)", "ECRT", inplace=True)
except Exception as NameError:
  pass

try:
  df['u_business_service'].mask(df['u_business_service'] == "Research Administration & Compliance Systems > Research Administration and Management > PI Dashboard", "PI_Dashboard", inplace=True)
except Exception as NameError:
  pass

try:
  df['u_business_service'].mask(df['u_business_service'] == "Research Administration & Compliance Systems > Research Compliance > Data Safety", "Data_Safety", inplace=True)
except Exception as NameError:
  pass

try:
  df['u_business_service'].mask(df['u_business_service'] == "Research Administration & Compliance Systems > Research Compliance > IRB (ESTR)", "IRB", inplace=True)
except Exception as NameError:
  pass

try:
  df['u_business_service'].mask(df['u_business_service'] == "Research Administration & Compliance Systems > Research Administration and Management > Grants Management (GMAS)", "GMAS", inplace=True)
except Exception as NameError:
  pass

try:
  df['u_business_service'].mask(df['u_business_service'] == "Research Administration & Compliance Systems > Research Compliance > Outside Activity and Interest Reporting (OAIR)", "OAIR", inplace=True)
except Exception as NameError:
  pass

try:
  df['u_business_service'].mask(df['u_business_service'] == "Research Administration & Compliance Systems > Research Compliance > Agreements", "Agreements", inplace=True)
except Exception as NameError:
  pass

try:
  df['u_business_service'].mask(df['u_business_service'] == "Research Administration & Compliance Systems > Research Administration and Management > Research Administration Portal", "Research Admin Portal", inplace=True)
except Exception as NameError:
  pass

# %%
print(df.assignment_group.unique())
#getting a Dataframe with only cancelled tickets
cancelled_tickets_df = df[df.incident_state=='Cancelled']
cancelled_tickets_df.shape
print(df.shape)
df = df[df.incident_state != "Cancelled"]
print(df.shape)
cancelled_tickets_df['month'] = pd.DatetimeIndex(cancelled_tickets_df['sys_created_on']).month
# Out:
# ['ATS - OAIR Functional' 'ATS - Research Admin Functional'
#  'ATS - Data Safety Functional' 'ATS-RACR-Functional'
#  'ATS - ESTR Functional' 'ATS - Research Administration Portal Functional'
#  'ATS - OSP ECRT Functional' 'ATS - DUA Functional'
#  'ATS - Research Admin - Technical' 'ATS - Research Admin - Dashboard']
# (2236, 23)
# (2056, 23)
# <ipython-input-21-73549e1d4fac>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cancelled_tickets_df['month'] = pd.DatetimeIndex(cancelled_tickets_df['sys_created_on']).month

# %%
cancelled_tickets_df.u_business_service.value_counts()
# Out:
# u_business_service
# IRB                      74
# OAIR                     56
# Data_Safety              39
# RACR                      5
# Research Admin Portal     3
# Agreements                1
# GMAS                      1
# ECRT                      1
# Name: count, dtype: int64

# %%
df.u_business_service.value_counts()
# Out:
# u_business_service
# GMAS                     589
# IRB                      312
# ECRT                     292
# OAIR                     284
# RACR                     235
# Data_Safety              211
# Agreements                69
# PI_Dashboard              45
# Research Admin Portal     19
# Name: count, dtype: int64

# %%
# group_names = df['u_business_service'].unique()
# print(group_names , "\n")
# print(df.assignment_group.unique(),"\n")
# print(df.u_issue_code.unique())

# %%
# group_names = df['u_business_service'].unique()
# print(group_names)

# %%
df['u_business_service'].unique()
# Out:
# array(['OAIR', 'GMAS', 'Data_Safety', 'RACR', 'IRB',
#        'Research Admin Portal', 'ECRT', 'PI_Dashboard', 'Agreements'],
#       dtype=object)

# %%
RACR_df = df.loc[df["u_business_service"] == "RACR", :]
ECRT_df = df.loc[df["u_business_service"] == "ECRT", :]
PI_Dashboard_df = df.loc[df["u_business_service"] == "PI_Dashboard", :]
Data_Safety_df = df.loc[df["u_business_service"] == "Data_Safety", :]
IRB_df = df.loc[df["u_business_service"] == "IRB", :]
GMAS_df = df.loc[df["u_business_service"] == "GMAS", :]
OAIR_df = df.loc[df["u_business_service"] == "OAIR", :]
Agreements_df = df.loc[df["u_business_service"] == "Agreements", :]
Admin_Portal_df = df.loc[df["u_business_service"] == "Research Admin Portal", :]

# %%
print(f"The shape of RACR_df is {RACR_df.shape}")
print(f"The shape of ECRT_df is {ECRT_df.shape}")
print(f"The shape of PI_Dashboard_df is {PI_Dashboard_df.shape}")
print(f"The shape of Data_Safety_df is {Data_Safety_df.shape}")
print(f"The shape of IRB_df is {IRB_df.shape}")
print(f"The shape of GMAS_df is {GMAS_df.shape}")
print(f"The shape of OAIR_df is {OAIR_df.shape}")
print(f"The shape of Agreements_df is {Agreements_df.shape}")
print(f"The shape of Admin_Portal_df is {Admin_Portal_df.shape}")
# Out:
# The shape of RACR_df is (235, 23)
# The shape of ECRT_df is (292, 23)
# The shape of PI_Dashboard_df is (45, 23)
# The shape of Data_Safety_df is (211, 23)
# The shape of IRB_df is (312, 23)
# The shape of GMAS_df is (589, 23)
# The shape of OAIR_df is (284, 23)
# The shape of Agreements_df is (69, 23)
# The shape of Admin_Portal_df is (19, 23)

# %%
# add month value to GMAS dataframe
GMAS_df['month'] = pd.DatetimeIndex(GMAS_df['sys_created_on']).month
# Out:
# <ipython-input-29-1d1a5047a89f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   GMAS_df['month'] = pd.DatetimeIndex(GMAS_df['sys_created_on']).month

# %%
RACR_df.u_issue_code.value_counts()
# Out:
# u_issue_code
# Request                145
# Distribution            31
# Enhancement/Backlog     12
# Bug fix/Backlog         12
# New/AdHoc               12
# Guidance                12
# Reuse/AdHoc              6
# Other                    2
# New/Backlog              2
# Content Changes          1
# Name: count, dtype: int64

# %%
# from pandas.core.resample import TimedeltaConvertibleTypes
def top_issue_codes(title,dataframe, service, groupby_category, fig_size_x, fig_size_y):
  top_issues_df = pd.DataFrame(dataframe.groupby([groupby_category])[service].count().sort_values(ascending=False))

  fig = df2img.plot_dataframe(
      top_issues_df,
      title=dict(
          font_color="darkred",
          font_family="Times New Roman",
          font_size=24,
          text=title,

          xanchor="left",
      ),
      fig_size=(fig_size_x, fig_size_y),
  )
  df2img.save_dataframe(fig=fig, filename="/content/drive/MyDrive/Report images/"+title+".png")

# %%
top_issue_codes("RACR Top Issue Codes",RACR_df, "u_business_service", "u_issue_code", 500, 140)
top_issue_codes("ECRT Top Issue Codes",ECRT_df, "u_business_service", "u_issue_code", 500, 260)
top_issue_codes("PI Dashboard Top Issue Codes",PI_Dashboard_df, "u_business_service", "u_issue_code", 500, 140)
top_issue_codes("Data Safety Top Issue Codes",Data_Safety_df, "u_business_service", "u_issue_code", 500, 200)
top_issue_codes("IRB Top Issue Codes",IRB_df, "u_business_service", "u_issue_code", 500, 300)
top_issue_codes("GMAS Top Issue Codes",GMAS_df, "u_business_service", "u_issue_code", 500, 660)
top_issue_codes("OAIR Top Issue Codes",OAIR_df, "u_business_service", "u_issue_code", 500, 260)
top_issue_codes("Agreements Top Issue Codes",Agreements_df, "u_business_service", "u_issue_code", 500, 200)
top_issue_codes("Admin Portal Top Issue Codes",Admin_Portal_df, "u_business_service", "u_issue_code", 500, 150)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-32-7df96ba279fb> in <cell line: 1>()
# ----> 1 top_issue_codes("RACR Top Issue Codes",RACR_df, "u_business_service", "u_issue_code", 500, 140)
#       2 top_issue_codes("ECRT Top Issue Codes",ECRT_df, "u_business_service", "u_issue_code", 500, 260)
#       3 top_issue_codes("PI Dashboard Top Issue Codes",PI_Dashboard_df, "u_business_service", "u_issue_code", 500, 140)
#       4 top_issue_codes("Data Safety Top Issue Codes",Data_Safety_df, "u_business_service", "u_issue_code", 500, 200)
#       5 top_issue_codes("IRB Top Issue Codes",IRB_df, "u_business_service", "u_issue_code", 500, 300)
#
# <ipython-input-31-cf561b4253eb> in top_issue_codes(title, dataframe, service, groupby_category, fig_size_x, fig_size_y)
#      15       fig_size=(fig_size_x, fig_size_y),
#      16   )
# ---> 17   df2img.save_dataframe(fig=fig, filename="/content/drive/MyDrive/Report images/"+title+".png")
#
# /usr/local/lib/python3.10/dist-packages/df2img/main.py in save_dataframe(fig, filename)
#     209
#     210     """
# --> 211     fig.write_image(filename)
#     212
#     213     return None
#
# /usr/local/lib/python3.10/dist-packages/plotly/basedatatypes.py in write_image(self, *args, **kwargs)
#    3838         import plotly.io as pio
#    3839
# -> 3840         return pio.write_image(self, *args, **kwargs)
#    3841
#    3842     # Static helpers
#
# /usr/local/lib/python3.10/dist-packages/plotly/io/_kaleido.py in write_image(fig, file, format, scale, width, height, validate, engine)
#     295         # We previously succeeded in interpreting `file` as a pathlib object.
#     296         # Now we can use `write_bytes()`.
# --> 297         path.write_bytes(img_data)
#     298
#     299
#
# /usr/lib/python3.10/pathlib.py in write_bytes(self, data)
#    1141         # type-check for the buffer interface before truncating the file
#    1142         view = memoryview(data)
# -> 1143         with self.open(mode='wb') as f:
#    1144             return f.write(view)
#    1145
#
# /usr/lib/python3.10/pathlib.py in open(self, mode, buffering, encoding, errors, newline)
#    1117         if "b" not in mode:
#    1118             encoding = io.text_encoding(encoding)
# -> 1119         return self._accessor.open(self, mode, buffering, encoding, errors,
#    1120                                    newline)
#    1121
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/Report images/RACR Top Issue Codes.png'

# %%
## Parameters - title, dataframe, column name that you want a count of, categories/hue, x_scale, top_x:
def plot_df(title, dataframe,count_col,categories, xscale, top_x ):
  """
  Enter the dataframe you want to plot as the first argument.
  Enter the name of the column in quotes for the second argument.
  The third argument determines the hue; pick a column that you want
  to represent with different colors. Xscale number adjusts the tick marks.
  Top_x is to select the top x items to display
  """
  sns.set_theme(style="darkgrid", rc={'figure.figsize':(12,8)})
  g = sns.countplot(data=dataframe, y=count_col, hue=categories, palette="husl", order=dataframe[count_col].value_counts().iloc[:top_x].index)
  g.set_title(title, fontsize=15)
  # g.set_xticks(range(dataframe["month"].value_counts().max()))
  g.set_xticks(range(0,dataframe.groupby([count_col], sort=True)['month'].value_counts().max()+8,xscale))

  g.set_xlabel("\n Count of Tickets")
  g.set_ylabel(count_col)

  ax = g.axes
  for p in ax.patches:
    ax.annotate(f'{p.get_width()}', (p.get_x() + p.get_width() + 2, p.get_y() + p.get_height() / 1.8), ha='center')
  plt.tight_layout()

  plt.savefig("/content/drive/MyDrive/Report images/"+title+".png")


def plot_df_issuecodes(title, dataframe,count_col,categories, xscale, top_x ):
  """
  Enter the dataframe you want to plot as the first argument.
  Enter the name of the column in quotes for the second argument.
  The third argument determines the hue; pick a column that you want
  to represent with different colors. Xscale number adjusts the tick marks.
  Top_x is to select the top x items to display
  """
  sns.set_theme(style="darkgrid", rc={'figure.figsize':(12,8)})
  g = sns.countplot(data=dataframe, y=count_col, hue=categories, palette="husl", order=dataframe[count_col].value_counts().iloc[:top_x].index)
  g.set_title(title, fontsize=15)

  g.set_xlabel("\n Count of Tickets")
  g.set_ylabel(count_col)
  plt.tight_layout()

  ax = g.axes
  for p in ax.patches:
    ax.annotate(str(int(p.get_width())), (p.get_x() + p.get_width() + 1.3, p.get_y() + p.get_height() / 1.3), ha='center')
    plt.tight_layout()

  plt.savefig("/content/drive/MyDrive/Report images/"+title+".png")

# %%
# try:
#   cancelled_tickets_df['u_business_service'].mask(cancelled_tickets_df['u_business_service'] == "Research Administration & Compliance Systems > Research Administration and Management > Research Administration & Compliance Reporting", "RACR", inplace=True)
# except Exception as NameError:
#   pass

# try:
#   cancelled_tickets_df['u_business_service'].mask(cancelled_tickets_df['u_business_service'] == "Research Administration & Compliance Systems > Research Administration and Management > Effort Reporting (ECRT)", "ECRT", inplace=True)
# except Exception as NameError:
#   pass

# try:
#   cancelled_tickets_df['u_business_service'].mask(cancelled_tickets_df['u_business_service'] == "Research Administration & Compliance Systems > Research Administration and Management > PI Dashboard", "PI_Dashboard", inplace=True)
# except Exception as NameError:
#   pass

# try:
#   cancelled_tickets_df['u_business_service'].mask(cancelled_tickets_df['u_business_service'] == "Research Administration & Compliance Systems > Research Compliance > Data Safety", "Data_Safety", inplace=True)
# except Exception as NameError:
#   pass

# try:
#   cancelled_tickets_df['u_business_service'].mask(cancelled_tickets_df['u_business_service'] == "Research Administration & Compliance Systems > Research Compliance > IRB (ESTR)", "IRB", inplace=True)
# except Exception as NameError:
#   pass

# try:
#   cancelled_tickets_df['u_business_service'].mask(cancelled_tickets_df['u_business_service'] == "Research Administration & Compliance Systems > Research Administration and Management > Grants Management (GMAS)", "GMAS", inplace=True)
# except Exception as NameError:
#   pass

# try:
#   cancelled_tickets_df['u_business_service'].mask(cancelled_tickets_df['u_business_service'] == "Research Administration & Compliance Systems > Research Compliance > Outside Activity and Interest Reporting (OAIR)", "OAIR", inplace=True)
# except Exception as NameError:
#   pass

# try:
#   cancelled_tickets_df['u_business_service'].mask(cancelled_tickets_df['u_business_service'] == "Research Administration & Compliance Systems > Research Compliance > Agreements", "Agreements", inplace=True)
# except Exception as NameError:
#   pass

# try:
#   cancelled_tickets_df['u_business_service'].mask(cancelled_tickets_df['u_business_service'] == "Research Administration & Compliance Systems > Research Administration and Management > Research Administration Portal", "Research Admin Portal", inplace=True)
# except Exception as NameError:
#   pass

# %%
def plot_df(title, dataframe,count_col,categories, xscale, top_x ):
  """
  Enter the dataframe you want to plot as the first argument.
  Enter the name of the column in quotes for the second argument.
  The third argument determines the hue; pick a column that you want
  to represent with different colors. Xscale number adjusts the tick marks.
  Top_x is to select the top x items to display
  """
  sns.set_theme(style="darkgrid", rc={'figure.figsize':(12,8)})
  g = sns.countplot(data=dataframe, y=count_col, hue=categories, palette="husl", order=dataframe[count_col].value_counts().iloc[:top_x].index)
  g.set_title(title, fontsize=15)
  # g.set_xticks(range(dataframe["month"].value_counts().max()))
  g.set_xticks(range(0,dataframe.groupby([count_col], sort=True)['month'].value_counts().max()+8,xscale))

  g.set_xlabel("\n Count of Tickets")
  g.set_ylabel(count_col)

  ax = g.axes
  for p in ax.patches:
    ax.annotate(str(int(p.get_width())), (p.get_x() + p.get_width() + 1.3, p.get_y() + p.get_height() / 1.3), ha='center')
    plt.tight_layout()

plot_df("Cancelled Tickets by Service", cancelled_tickets_df, "incident_state", "u_business_service", 5, 8)

# %%
agg_df = df['Service_Group'].value_counts()
# agg_df

agg_df.head()

# %%
def aggregate(title,columns,df):

    # print(data['name'].value_counts()['sravan'])

    # printing only H-Apps
    aggdf = df[ columns ].value_counts()['H-Apps']
    print( f"{type(aggdf)}" )
    print(df[columns ].value_counts()['H-Apps'])

    # create barplot using seaborn
    #ax = sns.barplot(x="H-Apps", y=aggdf.values)

    # # add value labels on barplot
    # for bars in ax.containers:
    #   print( {type(bars)} )
    #   ax.bar_label(bars)

    # plt.title(title, fontsize=16)
    # plt.xlabel("Application")
    # plt.ylabel("Count of Tickets")

    # plt.tight_layout()
    # plt.savefig("/content/drive/MyDrive/Aggregate Tickets by Application")


# aggregate("Aggregate Tickets by Application \n",'Service_Group',df)
aggregate("Aggregate Tickets by Application \n",'Service_Group',df)
# Out:
# <class 'numpy.int64'>
# 1070

# %%
def plot_df(title, dataframe,count_col,categories, xscale, top_x ):
  """
  Enter the dataframe you want to plot as the first argument.
  Enter the name of the column in quotes for the second argument.
  The third argument determines the hue; pick a column that you want
  to represent with different colors. Xscale number adjusts the tick marks.
  Top_x is to select the top x items to display
  """
  sns.set_theme(style="darkgrid", rc={'figure.figsize':(12,8)})
  g = sns.countplot(data=dataframe, y=count_col, hue=categories, palette="husl", order=dataframe[count_col].value_counts().iloc[:top_x].index)
  g.set_title(title, fontsize=15)
  # g.set_xticks(range(dataframe["month"].value_counts().max()))
  g.set_xticks(range(0,dataframe.groupby([count_col], sort=True)['month'].value_counts().max()+8,xscale))

  g.set_xlabel("\n Count of Tickets")
  g.set_ylabel(count_col)

  ax = g.axes
  for p in ax.patches:
    ax.annotate(str(int(p.get_width())), (p.get_x() + p.get_width() + 1.3, p.get_y() + p.get_height() / 1.3), ha='center')
    plt.tight_layout()

  plt.savefig("/content/drive/MyDrive/Report images/"+title+".png")

plot_df("Monthly Total Tickets by Service", df, "u_business_service", "month", 5, 8)

# add value labels on plot

# %%
plot_df("RACR Top 6 Issue Codes by Month", RACR_df, "u_issue_code", "month",2, 5)

# %%
plot_df_issuecodes("RACR Issue Codes Breakdown", RACR_df, "u_issue_code", "u_category",5, 8)

# %%
plot_df("ECRT Top 6 Issue Codes by Month", ECRT_df, "u_issue_code", "month", 2, 6)

# %%
plot_df_issuecodes("ECRT Issue Codes Breakdown", ECRT_df, "u_issue_code", "u_category",6, 6)

# %%
plot_df("PI Dashboard Top 6 Issue Codes by Month", PI_Dashboard_df, "u_issue_code", "month",1,6)

# %%
plot_df("Data Safety Top 6 Issue Codes by Month", Data_Safety_df, "u_issue_code", "month", 1, 5)

# %%
plot_df_issuecodes("Data Safety Issue Codes Breakdown", Data_Safety_df, "u_issue_code", "u_category",6, 6)

# %%
plot_df("IRB Top 6 Issue Codes by Month", IRB_df, "u_issue_code", "month",1,6)

# %%
plot_df_issuecodes("IRB Issue Codes Breakdown", IRB_df, "u_issue_code", "u_category",6, 6)

# %%
plot_df("GMAS Top 6 Issue Codes by Month", GMAS_df, "u_issue_code", "month", 2, 6)

# %%
plot_df_issuecodes("GMAS Issue Codes Breakdown", GMAS_df, "u_issue_code", "u_category",6, 6)

# %%
plot_df("OAIR Top 6 Issue Codes by Month", OAIR_df, "u_issue_code", "month", 2, 6)

# %%
plot_df_issuecodes("OAIR Issue Codes Breakdown", OAIR_df, "u_issue_code", "u_category",6, 6)

# %%
plot_df("Agreements Top 6 Issue Codes by Month", Agreements_df, "u_issue_code", "month", 1, 6)

# %%
plot_df_issuecodes("Agreements Issue Codes Breakdown", Agreements_df, "u_issue_code", "u_category",6, 6)

# %%
from wordcloud import WordCloud  #pip install wordcloud
from textblob import TextBlob  #Sentiment Analysis - pip install textblob
import matplotlib.pyplot as plt

train_qs = pd.Series(df['short_description'].tolist())
qs_text = " ".join(map(str, train_qs))

cloud = WordCloud(width=1440, height=1080).generate(qs_text)
plt.figure(figsize=(15, 10))
plt.imshow(cloud);
plt.axis('off');
plt.savefig("/content/drive/MyDrive/Report images/short_descriptions_wordcloud")

# %%
df['close_notes'] = df['close_notes'].fillna(" ")

# %%
train_qs = pd.Series(df['close_notes'].tolist())
qs_text = " ".join(train_qs)

cloud = WordCloud(width=1440, height=1080).generate(qs_text)
plt.figure(figsize=(15, 10))
plt.imshow(cloud);
plt.axis('off');
plt.tight_layout()
plt.savefig("/content/drive/MyDrive/Report images/close_notes_wordcloud")

# %%
def aggregate(rows,columns,df):
    column_keys = df[columns].unique()
    row_keys = df[rows].unique()

    agg = { key : [ len(df[(df[rows]==value) & (df[columns]==key)]) for value in row_keys]
               for key in column_keys }

    aggdf = pd.DataFrame(agg,index = row_keys)
    aggdf.index.rename(rows,inplace=True)

    # return aggdf
    aggdf.plot(kind='bar', stacked=True)
    plt.title("Aggregate Tickets by Application \n", fontsize=16)
    plt.yticks(np.arange(0, 200, step=10))
    plt.xlabel("Application")
    plt.ylabel("Count of Tickets")

    plt.tight_layout()

    plt.savefig("/content/drive/MyDrive/Report images/Aggregate Tickets by Application")

# aggregate('u_business_service','u_business_service',df).plot(kind='bar',stacked=True)
# aggregate('u_business_service','u_business_service',df)

# %%
# aggregate('Service_Group','Service_Group',df)

# %%
# !pip install fpdf2
from fpdf import FPDF
import datetime
from datetime import datetime, timedelta

# %%
WIDTH = 210
HEIGHT = 297

# %%
import os
os.chdir("/content/drive/MyDrive/Report images")

images = os.listdir()

# %%
images_path = "/content/drive/MyDrive/Report images/"

images_path_list = []

for image in images:
  image_path = images_path+image
  images_path_list.append(image_path)

images_path_list

# %%
def create_title(pdf, day):
  pdf.set_font('Arial', '', 24)
  pdf.ln(60)
  pdf.write(5, f"ServiceNow Quarterly Report")
  pdf.set_font('Arial', '', 16)
  pdf.ln(10)
  pdf.write(5, f"FY24 Quarter III Ticket Review Meeting")
  pdf.ln(150)
  pdf.write(30, f"Report generated on {day}")

# %%
def create_report(day, filename="/content/drive/MyDrive/Service Now Report FY24_Q3.pdf"):
  pdf = FPDF()

  '''
  Title Page, Page 1
  '''

  pdf.add_page()
  pdf.image("/content/drive/MyDrive/harvard_letterhead.png", 0, 0, WIDTH)
  create_title(pdf, day)

  '''
  Page 2, Ticket Volume Overview Page
  '''

  pdf.add_page()
  pdf.set_font('Arial', 'B', 16)
  pdf.cell(40,15, 'Ticket Volume Overview')

  pdf.set_font('Arial','',12)
  pdf.set_xy(10,20)
  pdf.cell(10,15, 'The report was created only looking at tickets created in SNOW in the date range specified above.')
  pdf.set_xy(10,25)
  pdf.cell(10,15, 'Cancelled tickets are excluded from this assessment.  Visual of cancelled tickets is presented later.')

  pdf.image("/content/drive/MyDrive/Report images/Aggregate Tickets by Application.png", 10 , 35, WIDTH-20)
  pdf.image("/content/drive/MyDrive/Report images/Monthly Total Tickets by Service.png", 10 , HEIGHT/2 + 10, WIDTH*.95 - 10)

  '''
  Page 3 - Top Issue Codes for GMAS, table only
  '''

  pdf.add_page()
  pdf.set_font('Arial', 'B', 14)
  pdf.cell(40,10, 'Top Issue Codes for GMAS')
  pdf.image("/content/drive/MyDrive/Report images/GMAS Top Issue Codes.png", 10 , 20, WIDTH*.8-10)

  '''
  Page 4 - Top Issue Codes for GMAS, chart
  '''
  pdf.add_page()
  pdf.set_font('Arial', 'B', 14)
  pdf.cell(40,10, 'Top Issue Codes for GMAS')
  pdf.image("/content/drive/MyDrive/Report images/GMAS Top 6 Issue Codes by Month.png", 10 , 20, WIDTH*.9-10)

  pdf.set_xy(10,HEIGHT/2-10)
  pdf.cell(40,10, 'GMAS Issue Codes BreakDown')
  pdf.image("/content/drive/MyDrive/Report images/GMAS Issue Codes Breakdown.png", 10 , HEIGHT/2 + 10, WIDTH*.95 - 10)

  # pdf.image("/content/drive/MyDrive/Work/Report Images/RACR Top Issue Codes.png", 10 , HEIGHT/2, WIDTH*.65)
  # pdf.image("/content/drive/MyDrive/Work/Report Images/RACR Top 6 Issue Codes by Month.png", 10 , HEIGHT/2+30, WIDTH*.8)


  '''
  Page 5 - Top Issue Codes for ECRT, table + chart
  '''
  pdf.add_page()
  pdf.set_font('Arial', 'B', 14)
  pdf.cell(40,10, 'Top Issue Codes for ECRT')
  pdf.image("/content/drive/MyDrive/Report images/ECRT Top 6 Issue Codes by Month.png", 10 , 20, WIDTH*.9-10)

  pdf.set_xy(10,HEIGHT/2-10)
  pdf.cell(40,10, 'ECRT Issue Codes BreakDown')
  pdf.image("/content/drive/MyDrive/Report images/ECRT Issue Codes Breakdown.png", 10 , HEIGHT/2 + 10, WIDTH*.95 - 10)

  '''
  Page 6 - Top Issue Codes IRB
  '''
  pdf.add_page()
  pdf.set_font('Arial', 'B', 14)
  pdf.cell(40,10, 'Top Issue Codes for IRB')
  pdf.image("/content/drive/MyDrive/Report images/IRB Top 6 Issue Codes by Month.png", 10 , 20, WIDTH*.9-10)

  pdf.set_xy(10,HEIGHT/2-10)
  pdf.cell(40,10, 'IRB Issue Codes BreakDown')
  pdf.image("/content/drive/MyDrive/Report images/IRB Issue Codes Breakdown.png", 10 , HEIGHT/2 + 10, WIDTH*.95 - 10)

  '''
  Page 7, Top Issue Codes for RACR
  '''
  pdf.add_page()
  pdf.set_font('Arial', 'B', 14)
  pdf.cell(40,10, 'Top Issue Codes for RACR')
  pdf.image("/content/drive/MyDrive/Report images/RACR Top 6 Issue Codes by Month.png", 10 , 20, WIDTH*.9-10)

  pdf.set_xy(10,HEIGHT/2-10)
  pdf.cell(40,10, 'RACR Issue Codes BreakDown')
  pdf.image("/content/drive/MyDrive/Report images/RACR Issue Codes Breakdown.png", 10 , HEIGHT/2 + 10, WIDTH*.95 - 10)

  '''
  Page 8, Top Issue Codes for OAIR
  '''
  pdf.add_page()
  pdf.set_font('Arial', 'B', 14)
  pdf.cell(40,10, 'Top Issue Codes for OAIR')
  pdf.image("/content/drive/MyDrive/Report images/OAIR Top 6 Issue Codes by Month.png", 10 , 20, WIDTH*.9-10)

  pdf.set_xy(10,HEIGHT/2-10)
  pdf.cell(40,10, 'RACR Issue Codes BreakDown')
  pdf.image("/content/drive/MyDrive/Report images/OAIR Issue Codes Breakdown.png", 10 , HEIGHT/2 + 10, WIDTH*.95 - 10)

  '''
  Page 9, Top Issue Codes for Data Safety
  '''
  pdf.add_page()
  pdf.set_font('Arial', 'B', 14)
  pdf.cell(40,10, 'Top Issue Codes for Data Safety')
  pdf.image("/content/drive/MyDrive/Report images/Data Safety Top 6 Issue Codes by Month.png", 10 , 20, WIDTH*.9-10)

  pdf.set_xy(10,HEIGHT/2-10)
  pdf.cell(40,10, 'Data Safety Issue Codes BreakDown')
  pdf.image("/content/drive/MyDrive/Report images/Data Safety Issue Codes Breakdown.png", 10 , HEIGHT/2 + 10, WIDTH*.95 - 10)

  '''
  Page 10, Top Issue Codes for Agreements
  '''
  pdf.add_page()
  pdf.set_font('Arial', 'B', 14)
  pdf.cell(40,10, 'Top Issue Codes for Agreements')
  pdf.image("/content/drive/MyDrive/Report images/Agreements Top 6 Issue Codes by Month.png", 10 , 20, WIDTH*.9-10)

  pdf.set_xy(10,HEIGHT/2-10)
  pdf.cell(40,10, 'Agreements Issue Codes BreakDown')
  pdf.image("/content/drive/MyDrive/Report images/Agreements Issue Codes Breakdown.png", 10 , HEIGHT/2 + 10, WIDTH*.95 - 10)

  '''
  Page 11, Cancelled Tickets by Service and close notes word cloud
  '''
  pdf.add_page()
  pdf.set_font('Arial', 'B', 16)
  pdf.cell(40,15, 'Cancelled Tickets by Service')

  pdf.image("/content/drive/MyDrive/Report images/Cancelled Tickets by Service.png", 10 , 25, WIDTH*.9-10)

  pdf.set_xy(10,HEIGHT/2-10)
  pdf.cell(40,10, 'Close Notes Word Cloud')
  pdf.image("/content/drive/MyDrive/Report images/close_notes_wordcloud.png", 10 , HEIGHT/2, WIDTH*.9)


  '''
  Page 12, Incident Descriptions word cloud
  '''
  pdf.add_page()
  pdf.set_font('Arial', 'B', 16)
  pdf.cell(40,15, 'Incident Short Descriptions Word Cloud')

  pdf.image("/content/drive/MyDrive/Report images/short_descriptions_wordcloud.png",10 , 20, WIDTH*.9)
  # count = 1
  # for image in images_path_list:
  #   if count == 1:
  #     pdf.add_page()
  #     # pdf.image(image, w=pdf.w*.75, h=pdf.h/2)
  #     # pdf.image(image, 10, 20, HEIGHT/2, WIDTH*.6)
  #     pdf.image(image, 10, 20, WIDTH*.6)
  #     pdf.ln(10)
  #     count = count + 1
  #   else:
  #     # pdf.image(image, w=pdf.w*.75, h=pdf.h/2)
  #     pdf.image(image, 10, HEIGHT/2 + 20, WIDTH*.6)
  #     pdf.ln(10)
  #     count = 1

  pdf.output(filename, 'F')

if __name__ == '__main__':
  day = datetime.today().strftime("%m/%d/%y")
  create_report(day)
